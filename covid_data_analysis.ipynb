# %%
# !pip install pyspark

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6728c5d2-f654-4fd0-bc66-070ca75e8bda" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6728c5d2-f654-4fd0-bc66-070ca75e8bda">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("covid.csv")
df.head()
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  08-04-20        367.0       30.0
# 1      AFG      Asia  Afghanistan  09-04-20        423.0       56.0
# 2      AFG      Asia  Afghanistan  10-04-20        484.0       61.0
# 3      AFG      Asia  Afghanistan  11-04-20        521.0       37.0
# 4      AFG      Asia  Afghanistan  12-04-20        555.0       34.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0              28.714          11.0         4.0                1.000  ...
# 1              33.000          14.0         3.0                1.429  ...
# 2              35.571          15.0         1.0                1.571  ...
# 3              40.857          15.0         0.0                1.571  ...
# 4              40.714          18.0         3.0                1.857  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("BigDataProject").getOrCreate()

df = spark.read.csv("covid.csv", header=True, inferSchema=True)
df.show(5)
# Out:
# +--------+---------+-----------+--------+-----------+---------+------------------+------------+----------+-------------------+-----------------------+---------------------+------------------------------+------------------------+----------------------+-------------------------------+---------+-----------+------------------------+----------------------+------------------+-------------------------------+--------------+-------------+-----------+----------------+----------+------------------+----------+-------------+-------------+--------------+---------------+---------------------+-------------------+--------------+------------+----------------------+--------------------------+---------------+-----------------------+
# ...

# %%
df.filter(df.location == "Turkey").show()
# Out:
# +--------+---------+--------+--------+-----------+---------+------------------+------------+----------+-------------------+-----------------------+---------------------+------------------------------+------------------------+----------------------+-------------------------------+---------+-----------+------------------------+----------------------+------------------+-------------------------------+--------------+-------------+---------------+----------------+----------+------------------+----------+-------------+-------------+--------------+---------------+---------------------+-------------------+--------------+------------+----------------------+--------------------------+---------------+-----------------------+
# ...

# %%
df.select("location","total_cases","total_deaths").show()
# Out:
# +-----------+-----------+------------+
# |   location|total_cases|total_deaths|
# +-----------+-----------+------------+
# |Afghanistan|        367|          11|
# |Afghanistan|        423|          14|
# |Afghanistan|        484|          15|
# |Afghanistan|        521|          15|
# |Afghanistan|        555|          18|
# |Afghanistan|        607|          18|
# |Afghanistan|        665|          21|
# |Afghanistan|        714|          23|
# |Afghanistan|        784|          25|
# |Afghanistan|        794|          29|
# |Afghanistan|        845|          30|
# |Afghanistan|        908|          30|
# |Afghanistan|        996|          33|
# |Afghanistan|       1031|          35|
# |Afghanistan|       1092|          36|
# |Afghanistan|       1176|          40|
# |Afghanistan|       1281|          42|
# |Afghanistan|       1351|          43|
# |Afghanistan|       1463|          47|
# |Afghanistan|       1531|          57|
# +-----------+-----------+------------+
# ...

# %%
df.orderBy(df.total_cases.desc()).show(50)
# Out:
# +--------+---------+--------+--------+-----------+---------+------------------+------------+----------+-------------------+-----------------------+---------------------+------------------------------+------------------------+----------------------+-------------------------------+---------+-----------+------------------------+----------------------+------------------+-------------------------------+--------------+-------------+-----------+----------------+----------+------------------+----------+-------------+-------------+--------------+---------------+---------------------+-------------------+--------------+------------+----------------------+--------------------------+---------------+-----------------------+
# ...
